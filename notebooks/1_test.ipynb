# %%
import sys
# sys.path.append(r"H:\3. Github3\lionel\src")
# sys.path.append(r"H:\3. Github3\lionel\\")
sys.path.append(r"H:\3. Github3\lionel")

# %%
from src.fantasy.scrape import Scraper

# %%
scraper = Scraper(23)

# %%
scraper.gw_stats
# Out:
# H:\3. Github3\lionel\src\fantasy\scrape.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gw_stats = gw_stats_current.append(gw_stats_previous)
#                    name position    team_name  assists  bps  creativity  \
# 0        Nathan Redmond      MID  Southampton        0    3         0.0
# 1      Junior Stanislas      MID  Bournemouth        0    3         0.0
# 2         Armando Broja      FWD      Chelsea        0    3         0.3
# 3          Fabian Schär      DEF    Newcastle        0   43        14.6
# 4           Jonny Evans      DEF    Leicester        0   15         1.3
# ...                 ...      ...          ...      ...  ...         ...
# 25442     Wilfred Ndidi      MID    Leicester        0    0         0.0
# 25443      Matt Ritchie      DEF    Newcastle        0    3         0.0
# 25444    Nathan Redmond      MID  Southampton        0    5         0.0
# ...

# %%
scraper.fixtures
# Out:
#                home         away  game_date  gameweek
# 0    Crystal Palace      Arsenal 2022-08-05         1
# 1            Fulham    Liverpool 2022-08-06         1
# 2       Bournemouth  Aston Villa 2022-08-06         1
# 3             Leeds       Wolves 2022-08-06         1
# 4         Newcastle   Nottingham 2022-08-06         1
# ..              ...          ...        ...       ...
# 375         Everton  Bournemouth 2023-05-28        38
# 376           Leeds    Tottenham 2023-05-28        38
# 377       Leicester     West Ham 2023-05-28        38
# 378  Manchester Utd       Fulham 2023-05-28        38
# 379     Southampton    Liverpool 2023-05-28        38
#
# [380 rows x 4 columns]
